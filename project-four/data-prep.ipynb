# %% [markdown]
# # Project 4: Web Scraping Job Postings

# %% [markdown]
# ## B. DATA PREPARATION

# %%
import glob
import pandas as pd
import re
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from collections import Counter

pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)

states = [ "AK",
                      "AL",
                      "AR",
                      "AS",
                      "AZ",
                      "CA",
                      "CO",
                      "CT",
                      "DC",
                      "DE",
                      "FL",
                      "GA",
                      "GU",
                      "HI",
                      "IA",
                      "ID",
                      "IL",
                      "IN",
                      "KS",
                      "KY",
                      "LA",
                      "MA",
                      "MD",
                      "ME",
                      "MI",
                      "MN",
                      "MO",
                      "MS",
                      "MT",
                      "NC",
                      "ND",
                      "NE",
                      "NH",
                      "NJ",
                      "NM",
                      "NV",
                      "NY",
                      "OH",
                      "OK",
                      "OR",
                      "PA",
                      "PR",
                      "RI",
                      "SC",
                      "SD",
                      "TN",
                      "TX",
                      "UT",
                      "VA",
                      "VI",
                      "VT",
                      "WA",
                      "WI",
                      "WV",
                      "WY"]

# %%
all_csv = glob.glob("*.csv")
jobs_df = pd.DataFrame()
list_ = []
for file_ in all_csv:
    df = pd.read_csv(file_, index_col=None, header=0)
    list_.append(df)
jobs_df = pd.concat(list_)

# %%
jobs_df.head()
# Out:
#    Unnamed: 0                                     category  \
# 0           0                       Information Technology
# 1           1              Information Technology, Banking
# 2           2                                   Consultant
# 3           3  Engineering, Information Technology, Design
# 4           4                                    Insurance
#
#                             company                  degree  \
# 0                            OPTOMI                     NaN
# 1  Information Technology Group LLC                     NaN
# 2         FRG Technology Consulting  Degree - 2 Year Degree
# 3            Robert Half Technology                     NaN
# 4                         BCforward           Degree - None
#
#                                              details employment_type  \
# 0  \nSenior Data Architect (AWS)\nOptomi, in part...       Full-Time
# 1  \nContract Only\n\n\nJob Summary:\nThis positi...      Contractor
# 2  \nAzure Data Architect-8 Months-90% Remote-100...      Contractor
# 3  \nRef ID: 03510-9501197370Classification: Data...       Full-Time
# 4  \nHighly desired experience with managing and ...      Contractor
#
#                                  experience  \
# 0   Experience - 8 to greater than 15 years
# 1           Experience - At least 6 year(s)
# 2           Experience - At least 3 year(s)
# 3                                  65 years
# 4  Experience - 12 to greater than 15 years
#
#                                industry  \
# 0          Banking - Financial Services
# 1          Banking - Financial Services
# 2                            Consulting
# 3  Computer Hardware, Computer Software
# 4          Healthcare - Health Services
#
#                                   location                           salary  \
# 0  921 East Fort AvenueBaltimore, MD 21230  $130,000.00 - $200,000.00 /Year
# 1                          Kansas City, MO                              NaN
# 2                             Columbus, IN          $100.00 - $130.00 /Hour
# 3                   Bartlesville, OK 74003            $48.00 - $60.00 /Hour
# 4                              Atlanta, GA                     $75.00 /Hour
#
#                                                title         travel
# 0                        Senior Data Architect (AWS)  Travel - None
# 1                                     Data Architect            NaN
# 2  Azure Data Architect-8 Months-90% Remote-100-1...            NaN
# 3                                     Data Architect            NaN
# 4                                 Database Architect  Travel - None

# %%
jobs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4200 entries, 0 to 299
# Data columns (total 12 columns):
# Unnamed: 0         4200 non-null int64
# category           4148 non-null object
# company            3924 non-null object
# degree             2134 non-null object
# details            4199 non-null object
# employment_type    4193 non-null object
# experience         3283 non-null object
# industry           4199 non-null object
# location           4197 non-null object
# salary             1919 non-null object
# title              4199 non-null object
# travel             881 non-null object
# dtypes: int64(1), object(11)
# memory usage: 426.6+ KB

# %%
# Drop "Unnamed: 0" column:
jobs_df = jobs_df.drop(columns="Unnamed: 0")

# Drop duplicate rows:
jobs_df = jobs_df.drop_duplicates()

# Drop the row without 'title' value:
jobs_df = jobs_df.dropna(subset=["title"])

# Drop the row which has "$20,000.00 commission" as the value in 'salary':
jobs_df = jobs_df[jobs_df["salary"] != "$20,000.00 commission"]

# Check number of rows now:
jobs_df.info()

# - Deal with other null values after cleaning up columns individually
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2807 entries, 0 to 299
# Data columns (total 11 columns):
# category           2773 non-null object
# company            2643 non-null object
# degree             1387 non-null object
# details            2807 non-null object
# employment_type    2802 non-null object
# experience         2159 non-null object
# industry           2807 non-null object
# location           2805 non-null object
# salary             1089 non-null object
# title              2807 non-null object
# travel             520 non-null object
# dtypes: object(11)
# memory usage: 263.2+ KB

# %%
# Inspect 'category' unique values:
job_categories = jobs_df['category'].unique()
unique_categories = []
for category_tag in job_categories:
    if type(category_tag) == str:
        categories_list = category_tag.split(", ")
        for category in categories_list:
            unique_categories.append(category.lower())
unique_categories = list(set(unique_categories))

print("Number of unique categories: {}".format(len(unique_categories)))
print("***")

# Encode 'category' to dummy variables manually:
categories_dict = {"cat_" + category: [] for category in unique_categories}

for each_row in jobs_df['category']:
    all_categories = [category for category in unique_categories]
    if type(each_row) == str:
        categories_list = each_row.split(", ")
        for category in categories_list:
            categories_dict["cat_" + category.lower()].append(1)
            all_categories.remove(category.lower())
        for category in all_categories:
            categories_dict["cat_" + category.lower()].append(0)
    else:
        for value in categories_dict.values():
            value.append(0)

for key, value in categories_dict.items():
    jobs_df[key] = value

jobs_df = jobs_df.drop(columns="category")
jobs_df.info()
# Out:
# Number of unique categories: 56
# ***
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2807 entries, 0 to 299
# Data columns (total 66 columns):
# company                               2643 non-null object
# degree                                1387 non-null object
# details                               2807 non-null object
# employment_type                       2802 non-null object
# experience                            2159 non-null object
# industry                              2807 non-null object
# location                              2805 non-null object
# salary                                1089 non-null object
# title                                 2807 non-null object
# travel                                520 non-null object
# cat_construction                      2807 non-null int64
# cat_consultant                        2807 non-null int64
# cat_pharmaceutical                    2807 non-null int64
# cat_media - journalism - newspaper    2807 non-null int64
# cat_facilities                        2807 non-null int64
# cat_science                           2807 non-null int64
# cat_health care                       2807 non-null int64
# cat_sales                             2807 non-null int64
# cat_manufacturing                     2807 non-null int64
# cat_insurance                         2807 non-null int64
# cat_qa - quality control              2807 non-null int64
# cat_banking                           2807 non-null int64
# cat_accounting                        2807 non-null int64
# cat_biotech                           2807 non-null int64
# cat_telecommunications                2807 non-null int64
# cat_admin - clerical                  2807 non-null int64
# cat_general labor                     2807 non-null int64
# cat_installation - maint - repair     2807 non-null int64
# cat_business opportunity              2807 non-null int64
# cat_supply chain                      2807 non-null int64
# cat_real estate                       2807 non-null int64
# cat_nonprofit - social services       2807 non-null int64
# cat_human resources                   2807 non-null int64
# cat_business development              2807 non-null int64
# cat_transportation                    2807 non-null int64
# cat_skilled labor - trades            2807 non-null int64
# cat_nurse                             2807 non-null int64
# cat_purchasing - procurement          2807 non-null int64
# cat_executive                         2807 non-null int64
# cat_strategy - planning               2807 non-null int64
# cat_training                          2807 non-null int64
# cat_education                         2807 non-null int64
# cat_entry level                       2807 non-null int64
# cat_other                             2807 non-null int64
# cat_legal                             2807 non-null int64
# cat_retail                            2807 non-null int64
# cat_restaurant - food service         2807 non-null int64
# cat_hospitality - hotel               2807 non-null int64
# cat_inventory                         2807 non-null int64
# cat_engineering                       2807 non-null int64
# cat_finance                           2807 non-null int64
# cat_government                        2807 non-null int64
# cat_professional services             2807 non-null int64
# cat_information technology            2807 non-null int64
# cat_customer service                  2807 non-null int64
# cat_legal admin                       2807 non-null int64
# cat_automotive                        2807 non-null int64
# cat_warehouse                         2807 non-null int64
# cat_marketing                         2807 non-null int64
# cat_design                            2807 non-null int64
# cat_research                          2807 non-null int64
# cat_management                        2807 non-null int64
# cat_government - federal              2807 non-null int64
# cat_grocery                           2807 non-null int64
# cat_general business                  2807 non-null int64
# cat_distribution - shipping           2807 non-null int64
# dtypes: int64(56), object(10)
# memory usage: 1.4+ MB

# %%
# Inspect 'industry' unique values:
job_industries = jobs_df['industry'].unique()
unique_industries = []
for industry_tag in job_industries:
    if type(industry_tag) == str:
        industries_list = industry_tag.split(", ")
        for industry in industries_list:
            unique_industries.append(industry.lower())
unique_industries = list(set(unique_industries))

print("Number of unique industries: {}".format(len(unique_industries)))
print("***")

# Encode 'industry' to dummy variables manually:
industries_dict = {"indus_" + industry: [] for industry in unique_industries}

for each_row in jobs_df['industry']:
    all_industries = [industry for industry in unique_industries]
    if type(each_row) == str:
        industries_list = each_row.split(", ")
        for industry in industries_list:
            industries_dict["indus_" + industry.lower()].append(1)
            all_industries.remove(industry.lower())
        for industry in all_industries:
            industries_dict["indus_" + industry.lower()].append(0)
    else:
        for value in industries_dict.values():
            value.append(0)

for key, value in industries_dict.items():
    jobs_df[key] = value

jobs_df = jobs_df.drop(columns="industry")
jobs_df.info()
# Out:
# Number of unique industries: 67
# ***
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2807 entries, 0 to 299
# Columns: 132 entries, company to indus_industrial
# dtypes: int64(123), object(9)
# memory usage: 2.8+ MB

# %%
# Inspect 'company' unique values:
unique_companies = list(set([company.lower() for company in jobs_df['company'].unique() if type(company) == str]))

print("Number of unique companies: {}".format(len(unique_companies)))
print("***")

# Encode 'company' to dummy variables manually:
companies_dict = {"comp_" + company: [] for company in unique_companies}

for company in jobs_df['company']:
    all_companies = [company for company in unique_companies]
    if type(each_row) == str:
        companies_dict["comp_" + company.lower()].append(1)
        all_companies.remove(company.lower())
        for remaining_company in all_companies:
            companies_dict["comp_" + remaining_company.lower()].append(0)
    else:
        for value in companies_dict.values():
            value.append(0) 

for key, value in companies_dict.items():
    jobs_df[key] = value

jobs_df = jobs_df.drop(columns="company")
jobs_df.info()
# Out:
# Number of unique companies: 951
# ***
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2807 entries, 0 to 299
# Columns: 1082 entries, degree to comp_3coast
# dtypes: int64(1074), object(8)
# memory usage: 23.2+ MB

# %%
# Inspect 'degree' unique values:
unique_degrees = []
for degree_tag in jobs_df['degree'].unique():
    if type(degree_tag) == str:
        degrees_list = degree_tag.split(" - ")
        unique_degrees.append(degrees_list[1].lower())
unique_degrees = list(set(unique_degrees))

# Encode 'degree' to dummy variables manually:
degrees_dict = {"deg_" + degree.lower(): [] for degree in unique_degrees}

for company in jobs_df['degree']:
    all_degrees = [degree.lower() for degree in unique_degrees]
    if type(each_row) == str:
        degrees_list = degree_tag.split(" - ")
        degree = degrees_list[1].lower()
        degrees_dict["deg_" + degree].append(1)
        all_degrees.remove(degree)
        for degree in all_degrees:
            degrees_dict["deg_" + degree].append(0)
    else:
        degrees_dict["deg_none"].append(1)
        all_degrees.remove("deg_none")
        for degree in all_degrees:
            degrees_dict["deg_" + degree].append(0)

for key, value in degrees_dict.items():
    jobs_df[key] = value

jobs_df = jobs_df.drop(columns="degree")
jobs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2807 entries, 0 to 299
# Columns: 1087 entries, details to deg_2 year degree
# dtypes: int64(1080), object(7)
# memory usage: 23.3+ MB

# %%
# Inspect 'employment_type' unique values:
unique_types = list(set([employ_type.lower() for employ_type in jobs_df['employment_type'].unique() if type(employ_type) == str]))

print("Number of unique employment types: {}".format(len(unique_types)))
print("***")

# Encode 'employment_type' to dummy variables manually:
types_dict = {"type_" + employ_type: [] for employ_type in unique_types}

for employ_type in jobs_df['employment_type']:
    all_types = [employ_type for employ_type in unique_types]
    if type(employ_type) == str:
        types_dict["type_" + employ_type.lower()].append(1)
        all_types.remove(employ_type.lower())
        for remaining_type in all_types:
            types_dict["type_" + remaining_type.lower()].append(0)
    else:
        for value in types_dict.values():
            value.append(0) 

for key, value in companies_dict.items():
    jobs_df[key] = value

jobs_df = jobs_df.drop(columns="employment_type")
jobs_df.info()
# Out:
# Number of unique employment types: 5
# ***
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2807 entries, 0 to 299
# Columns: 1086 entries, details to deg_2 year degree
# dtypes: int64(1080), object(6)
# memory usage: 23.3+ MB

# %%
# Inspect 'travel' unique values:
unique_travels = list(set([travel.lower() for travel in jobs_df['travel'].unique() if type(travel) == str]))

print("Number of unique travel requirements: {}".format(len(unique_travels)))
unique_travels
# Out:
# Number of unique travel requirements: 7
# ['travel - none',
#  'travel',
#  'travel - negligible',
#  'travel expenses',
#  'travel - up to 50%',
#  'travel - up to 25%',
#  'travel - road warrior']

# %%
jobs_df.loc[jobs_df["travel"] == "Travel", ["travel"]] = "travel - some"
jobs_df.loc[jobs_df["travel"] == "Travel Expenses", ["travel"]] = None

def get_split_value(string):
    if type(string) == str:
        return string.split(" - ")[-1].lower()
    else:
        return string

jobs_df["travel"] = jobs_df["travel"].apply(get_split_value)

# Inspect 'travel' unique values:
unique_travels = list(set([travel for travel in jobs_df['travel'].unique() if type(travel) == str]))

print("Number of unique travel requirements: {}".format(len(unique_travels)))
unique_travels
# Out:
# Number of unique travel requirements: 6
# ['none', 'up to 25%', 'some', 'negligible', 'up to 50%', 'road warrior']

# %%
# Encode 'travel' to dummy variables manually:
travel_dict = {"travel_" + req: [] for req in unique_travels}

for req in jobs_df['travel']:
    all_reqs = [req for req in unique_travels]
    if type(req) == str:
        travel_dict["travel_" + req].append(1)
        all_reqs.remove(req)
        for remaining_req in all_reqs:
            travel_dict["travel_" + remaining_req].append(0)
    else:
        for value in travel_dict.values():
            value.append(0) 

for key, value in travel_dict.items():
    jobs_df[key] = value

jobs_df = jobs_df.drop(columns="travel")
jobs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2807 entries, 0 to 299
# Columns: 1091 entries, details to travel_negligible
# dtypes: int64(1086), object(5)
# memory usage: 23.4+ MB

# %%
# Inspect 'location' unique values:
unique_locations = list(set([location for location in jobs_df['location'].unique() if type(location) == str]))

print("Number of unique locations: {}".format(len(unique_locations)))

# Encode 'location' to dummy variables manually, based on states:
states_dict = {"state_" + state: [] for state in states}

for location in jobs_df['location']:
    if type(location) == str:
        for state in states:
            if state in location:
                states_dict["state_" + state].append(1)
            else:
                states_dict["state_" + state].append(0)
    else:
        for state in states:
            states_dict["state_" + state].append(0)

for key, value in states_dict.items():
    jobs_df[key] = value

jobs_df = jobs_df.drop(columns="location")
jobs_df.info()
# Out:
# Number of unique locations: 1213
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2807 entries, 0 to 299
# Columns: 1145 entries, details to state_WV
# dtypes: int64(1141), object(4)
# memory usage: 24.5+ MB

# %%
# Inspect 'salary' unique values:
print(len(jobs_df['salary'].unique()))
jobs_df['salary'].unique()[:10]
# Out:
# 520
# array(['$130,000.00 - $200,000.00 /Year', nan, '$100.00 - $130.00 /Hour',
#        '$48.00 - $60.00 /Hour', '$75.00 /Hour',
#        '$155,000.00 - $185,000.00 /Year',
#        '$130,000.00 - $150,000.00 /Year',
#        '$115,000.00 - $125,000.00 /Year',
#        '$170,000.00 - $180,000.00 /Year',
#        '$130,000.00 - $170,000.00 /Year'], dtype=object)

# %%
# Convert:
# - hourly salary to yearly salary
# - salary range to max, min and average salary

annual_work_hours = 2008 #Taken from https://www.calendar-12.com/working_days/2018

salary_dict = {
    "salary_min": [],
    "salary_max": [],
    "salary_avg": []
}

def get_salary_values(salary_range): 
    if type(salary_range) == str:
        if 'Year' in salary_range:
            sal = re.findall(r'[0-9.]+', salary_range.replace('$','').replace(',',''))
            sal = [float(element) for element in sal]
#             print sal
            if len(sal) == 2:
                salary_dict["salary_min"].append(sal[0])
                salary_dict["salary_max"].append(sal[1])
                salary_dict["salary_avg"].append(np.mean([sal[0], sal[1]]))
            else:
                salary_dict["salary_min"].append(sal[0])
                salary_dict["salary_max"].append(sal[0])
                salary_dict["salary_avg"].append(sal[0])
                
        elif 'Hour' in salary_range:
            sal = re.findall(r'[0-9.]+',salary_range.replace('$','').replace(',',''))
            sal = [float(element) for element in sal]
#             print sal
            if len(sal) == 2:
                salary_dict["salary_min"].append(sal[0] * annual_work_hours)
                salary_dict["salary_max"].append(sal[1] * annual_work_hours)
                salary_dict["salary_avg"].append(np.mean([sal[0], sal[1]]) * annual_work_hours)
            else:
                salary_dict["salary_min"].append(sal[0] * annual_work_hours)
                salary_dict["salary_max"].append(sal[0] * annual_work_hours)
                salary_dict["salary_avg"].append(sal[0] * annual_work_hours)
        else:
            print salary_range
        
    else:
#         print salary_range
        salary_dict["salary_min"].append(None)
        salary_dict["salary_max"].append(None)
        salary_dict["salary_avg"].append(None)


        
for salary_range in jobs_df['salary']:
    get_salary_values(salary_range)

for key, value in salary_dict.items():
    jobs_df[key] = value
    
jobs_df = jobs_df.drop(columns="salary")

jobs_df.info()

# for key, value in salary_dict.items():
#     print "length of {}: {}".format(key, len(value))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2807 entries, 0 to 299
# Columns: 1147 entries, details to salary_max
# dtypes: float64(3), int64(1141), object(3)
# memory usage: 24.6+ MB

# %%
# function returns mid point of a given experience range, else pass if no data available
# values above 15 are then removed as they are likely to refer to company age
def experience_cleaner(exp_range):
    if type(exp_range) == str:
        if "None" in exp_range:
            return 0
        else:
            experience = np.mean([float(i) for i in re.findall(r'[0-9]+', exp_range)])
            if experience > 15:
                return np.NaN
            else:
                return experience
    else:
        return np.NaN

jobs_df["experience"] = jobs_df["experience"].apply(experience_cleaner)

# %%
# Use the CountVectorizer to find unigrams for most common job titles: 
vect = CountVectorizer()

# Pulls all of job titles into one giant string
title_string = "".join(jobs_df['title'])
title_unigrams = vect.build_analyzer()(title_string)

Counter(title_unigrams).most_common(50)
# Out:
# [(u'data', 460),
#  (u'analyst', 307),
#  (u'business', 252),
#  (u'intelligence', 150),
#  (u'engineer', 144),
#  (u'developer', 140),
#  (u'analystbusiness', 122),
#  (u'database', 122),
#  (u'analystdata', 115),
#  (u'bi', 99),
#  (u'scientist', 92),
#  (u'software', 70),
#  (u'analystsenior', 68),
#  (u'sql', 66),
#  (u'scientistdata', 64),
#  (u'administrator', 59),
#  (u'and', 57),
#  (u'senior', 49),
#  (u'architect', 49),
#  (u'net', 44),
#  (u'engineerdata', 43),
#  (u'engineersenior', 42),
#  (u'developerdatabase', 41),
#  (u'dba', 41),
#  (u'financial', 40),
#  (u'server', 40),
#  (u'analystsr', 36),
#  (u'oracle', 35),
#  (u'programmer', 32),
#  (u'of', 30),
#  (u'analytics', 29),
#  (u'architectdata', 29),
#  (u'developersenior', 28),
#  (u'analystfinancial', 27),
#  (u'or', 26),
#  (u'level', 25),
#  (u'learning', 25),
#  (u'analystit', 25),
#  (u'research', 24),
#  (u'stack', 24),
#  (u'it', 23),
#  (u'manager', 23),
#  (u'lead', 23),
#  (u'big', 22),
#  (u'developerbusiness', 22),
#  (u'java', 22),
#  (u'administratordatabase', 22),
#  (u'engineersoftware', 21),
#  (u'scientistsenior', 21),
#  (u'developersr', 20)]

# %%
# Convert all job titles to lowercase:
jobs_df["title"] = jobs_df["title"].str.lower()

jobs_df['title_intern'] = np.where(jobs_df['title'].str.contains("intern|internship"), 1, 0)
jobs_df['title_lead'] = np.where(jobs_df['title'].str.contains("lead"), 1, 0)
jobs_df['title_principal'] = np.where(jobs_df['title'].str.contains("principal"), 1, 0)
jobs_df['title_chief'] = np.where(jobs_df['title'].str.contains("chief"), 1, 0)
jobs_df['title_senior'] = np.where(jobs_df['title'].str.contains("senior|sr"), 1, 0)
jobs_df['title_junior'] = np.where(jobs_df['title'].str.contains("junior|jr"), 1, 0)

jobs_df['title_data'] = np.where(jobs_df['title'].str.contains("data"), 1, 0)
jobs_df['title_ml'] = np.where(jobs_df['title'].str.contains("machine learning|ml"), 1, 0)
jobs_df['title_database'] = np.where(jobs_df['title'].str.contains("database|dba"), 1, 0)
jobs_df['title_ai'] = np.where(jobs_df['title'].str.contains("artificial intelligence|ai"), 1, 0)
jobs_df['title_business'] = np.where(jobs_df['title'].str.contains("business|bi"), 1, 0)
jobs_df['title_software'] = np.where(jobs_df['title'].str.contains("software"), 1, 0)
jobs_df['title_sql'] = np.where(jobs_df['title'].str.contains("sql"), 1, 0)
jobs_df['title_financial'] = np.where(jobs_df['title'].str.contains("financial"), 1, 0)

jobs_df['title_analyst'] = np.where(jobs_df['title'].str.contains("analyst|analytics"), 1, 0)
jobs_df['title_intelligence'] = np.where(jobs_df['title'].str.contains("intelligence|bi"), 1, 0)
jobs_df['title_engineer'] = np.where(jobs_df['title'].str.contains("engineer"), 1, 0)
jobs_df['title_developer'] = np.where(jobs_df['title'].str.contains("developer"), 1, 0)
jobs_df['title_scientist'] = np.where(jobs_df['title'].str.contains("scientist"), 1, 0)
jobs_df['title_administrator'] = np.where(jobs_df['title'].str.contains("administrator|dba"), 1, 0)
jobs_df['title_architect'] = np.where(jobs_df['title'].str.contains("architect"), 1, 0)

jobs_df = jobs_df.drop(columns="title")
jobs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2807 entries, 0 to 299
# Columns: 1167 entries, details to title_architect
# dtypes: float64(4), int64(1162), object(1)
# memory usage: 25.0+ MB

# %%
# Clean "details" column by removing formatting characters:
def details_cleaner(string):
    return ''.join(s if ord(s)>31 and ord(s)<126 else ' ' for s in string)

jobs_df["details"] = jobs_df["details"].map(details_cleaner)

# %%
# See final cleaned dataframe (not preprocessed yet for NLP)
jobs_df.head()

# Save dataframe to csv to load on other notebook:
jobs_df.to_csv('data-prep.csv', encoding='utf-8')

# - Will do feature selection in modelling part to decrease number of features

# %%
jobs_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2807 entries, 0 to 299
# Data columns (total 1167 columns):
# details                                                        object
# experience                                                     float64
# cat_construction                                               int64
# cat_consultant                                                 int64
# cat_pharmaceutical                                             int64
# cat_media - journalism - newspaper                             int64
# cat_facilities                                                 int64
# cat_science                                                    int64
# cat_health care                                                int64
# cat_sales                                                      int64
# cat_manufacturing                                              int64
# cat_insurance                                                  int64
# cat_qa - quality control                                       int64
# cat_banking                                                    int64
# cat_accounting                                                 int64
# cat_biotech                                                    int64
# cat_telecommunications                                         int64
# cat_admin - clerical                                           int64
# cat_general labor                                              int64
# cat_installation - maint - repair                              int64
# cat_business opportunity                                       int64
# cat_supply chain                                               int64
# cat_real estate                                                int64
# cat_nonprofit - social services                                int64
# cat_human resources                                            int64
# cat_business development                                       int64
# cat_transportation                                             int64
# cat_skilled labor - trades                                     int64
# cat_nurse                                                      int64
# cat_purchasing - procurement                                   int64
# cat_executive                                                  int64
# cat_strategy - planning                                        int64
# cat_training                                                   int64
# cat_education                                                  int64
# cat_entry level                                                int64
# cat_other                                                      int64
# cat_legal                                                      int64
# cat_retail                                                     int64
# cat_restaurant - food service                                  int64
# cat_hospitality - hotel                                        int64
# cat_inventory                                                  int64
# cat_engineering                                                int64
# cat_finance                                                    int64
# cat_government                                                 int64
# cat_professional services                                      int64
# cat_information technology                                     int64
# cat_customer service                                           int64
# cat_legal admin                                                int64
# cat_automotive                                                 int64
# cat_warehouse                                                  int64
# cat_marketing                                                  int64
# cat_design                                                     int64
# cat_research                                                   int64
# cat_management                                                 int64
# cat_government - federal                                       int64
# cat_grocery                                                    int64
# cat_general business                                           int64
# cat_distribution - shipping                                    int64
# indus_building materials                                       int64
# indus_semiconductor                                            int64
# indus_oil refining - petroleum - drilling                      int64
# indus_printing - publishing                                    int64
# indus_consumer products                                        int64
# indus_mortgage                                                 int64
# indus_other                                                    int64
# indus_computer hardware                                        int64
# indus_employment - recruiting - staffing                       int64
# indus_wireless                                                 int64
# indus_government - civil service                               int64
# indus_hotel - resort                                           int64
# indus_airline - aviation                                       int64
# indus_other great industries                                   int64
# indus_transportation                                           int64
# indus_environmental                                            int64
# indus_managed care                                             int64
# indus_social services                                          int64
# indus_credit - loan - collections                              int64
# indus_hospitality                                              int64
# indus_travel                                                   int64
# indus_automotive - motor vehicles - parts                      int64
# indus_security                                                 int64
# indus_restaurant                                               int64
# indus_food                                                     int64
# indus_exercise - fitness                                       int64
# indus_advertising                                              int64
# indus_homebuilding                                             int64
# indus_construction                                             int64
# indus_public relations                                         int64
# indus_merchandising                                            int64
# indus_banking - financial services                             int64
# indus_telecommunications                                       int64
# indus_newspaper                                                int64
# indus_art - photography - journalism                           int64
# indus_securities                                               int64
# indus_internet - ecommerce                                     int64
# indus_fashion - apparel - textile                              int64
# indus_retail                                                   int64
# indus_insurance                                                int64
# indus_real estate - property mgt                               int64
# indus_manufacturing                                            int64
# indus_healthcare - health services                             int64
# indus_hvac                                                     int64
# indus_medical equipment                                        int64
# indus_energy - utilities - gas - electric                      int64
# indus_biotechnology                                            int64
# indus_entertainment                                            int64
# indus_broadcasting - radio - tv                                int64
# indus_chemical                                                 int64
# indus_training                                                 int64
# indus_architecture - building                                  int64
# indus_sales - marketing                                        int64
# indus_military                                                 int64
# indus_legal                                                    int64
# indus_accounting - finance                                     int64
# indus_pharmaceutical                                           int64
# indus_not for profit - charitable                              int64
# indus_packaging                                                int64
# indus_defense - aerospace                                      int64
# indus_electronics                                              int64
# indus_office supplies - equipment                              int64
# indus_education - teaching - administration                    int64
# indus_consulting                                               int64
# indus_computer software                                        int64
# indus_agriculture                                              int64
# indus_industrial                                               int64
# comp_city of atlanta                                           int64
# comp_eckhardt trading company                                  int64
# comp_mitsubishi motors north america                           int64
# comp_quest financial                                           int64
# comp_kelly scientific resources                                int64
# comp_nwn corporation                                           int64
# comp_leaseplan usa                                             int64
# comp_rms computer corporation                                  int64
# comp_nucor corporation                                         int64
# comp_plastic executive recruiters                              int64
# comp_apple                                                     int64
# comp_stefanini                                                 int64
# comp_securitas eoc                                             int64
# comp_washington frank                                          int64
# comp_apn software services inc                                 int64
# comp_nationwide                                                int64
# comp_my new company                                            int64
# comp_carenational                                              int64
# comp_c2s consulting group                                      int64
# comp_it alliance                                               int64
# comp_children's hospital of philadelphia                       int64
# comp_the csi companies                                         int64
# comp_bayview asset management                                  int64
# comp_theoris                                                   int64
# comp_ultimate medical academy                                  int64
# comp_sni financial                                             int64
# comp_officeteam                                                int64
# comp_allergan                                                  int64
# comp_expedient                                                 int64
# comp_carey international, inc.                                 int64
# comp_systemtec                                                 int64
# comp_norton healthcare                                         int64
# comp_bcforward                                                 int64
# comp_humana                                                    int64
# comp_endevis                                                   int64
# comp_united nations federal credit union                       int64
# comp_cleveland business consultants llc                        int64
# comp_e-aspireit llc                                            int64
# comp_talascend                                                 int64
# comp_smart-tek                                                 int64
# comp_act                                                       int64
# comp_intercontinental exchange, inc.                           int64
# comp_david j. joseph                                           int64
# comp_johnson service group                                     int64
# comp_large financial client                                    int64
# comp_toyota boshoku america, inc                               int64
# comp_amerit consulting                                         int64
# comp_texas health resources                                    int64
# comp_national security agency (nsa)                            int64
# comp_sgt inc                                                   int64
# comp_dcs corporation                                           int64
# comp_grainger                                                  int64
# comp_network technologies international, inc.                  int64
# comp_ws packaging group inc.                                   int64
# comp_cei                                                       int64
# comp_micro tech staffing                                       int64
# comp_norc at the university of chicago                         int64
# comp_na ali'i                                                  int64
# comp_nauticus group                                            int64
# comp_qti group                                                 int64
# comp_mastech digital                                           int64
# comp_open systems technologies                                 int64
# comp_peak technical staffing usa                               int64
# comp_prestige staffing information technology job              int64
# comp_iconma                                                    int64
# comp_sedgwick claims management services, inc.                 int64
# comp_octo consulting group                                     int64
# comp_graham architectural products                             int64
# comp_kar auction services inc                                  int64
# comp_johnson technology systems inc.                           int64
# comp_compucom systems, inc.                                    int64
# comp_next step systems                                         int64
# comp_burnett specialists                                       int64
# comp_american systems                                          int64
# comp_the walters art museum                                    int64
# comp_skillstorm commercial services llc                        int64
# comp_cambrex                                                   int64
# comp_aerotek                                                   int64
# comp_bi worldwide                                              int64
# comp_bell & associates, inc.                                   int64
# comp_costar group                                              int64
# comp_computer world services (cws)corporation                  int64
# comp_federal reserve bank of atlanta                           int64
# comp_stevendouglas                                             int64
# comp_huxley associates                                         int64
# comp_confidential                                              int64
# comp_emblemhealth                                              int64
# comp_hilton corporate                                          int64
# comp_veterans sourcing group hq                                int64
# comp_aashvan llc                                               int64
# comp_insight global                                            int64
# comp_meredith corporation                                      int64
# comp_guideit llc                                               int64
# comp_warren averett staffing and recruiting                    int64
# comp_tata consultancy services                                 int64
# comp_frg technology consulting                                 int64
# comp_garmin                                                    int64
# comp_orion group                                               int64
# comp_aston carter                                              int64
# comp_emd serono                                                int64
# comp_true team partner                                         int64
# comp_empire blue cross blue shield                             int64
# comp_trustaff                                                  int64
# comp_syntelli solutions                                        int64
# comp_culturefit technology staffing                            int64
# comp_cornerstone staffing solutions, inc                       int64
# comp_perr&amp;knight                                           int64
# comp_connections it services                                   int64
# comp_wincorp solutions                                         int64
# comp_general motors                                            int64
# comp_nuvision federal credit union                             int64
# comp_sears home services                                       int64
# comp_morson international                                      int64
# comp_adp - automatic data processing                           int64
# comp_cybercoders                                               int64
# comp_meridian technologies                                     int64
# comp_bartech group                                             int64
# comp_imperial pfs                                              int64
# comp_proquest                                                  int64
# comp_diversant, llc                                            int64
# comp_kelly global talent solution                              int64
# comp_bluecross blueshield of south carolina                    int64
# comp_arjo                                                      int64
# comp_exl service                                               int64
# comp_equiant financial services                                int64
# comp_resolution technologies, inc.                             int64
# comp_assetmark                                                 int64
# comp_altec industries , inc.                                   int64
# comp_mark/ryan associates ltd                                  int64
# comp_bepc inc                                                  int64
# comp_ncs technologies, inc.                                    int64
# comp_merieux nutrisciences                                     int64
# comp_fojp service corporation                                  int64
# comp_north american bancard                                    int64
# comp_midwest energy &amp; communications                       int64
# comp_allied reliability group                                  int64
# comp_atrium staffing                                           int64
# comp_clarus group                                              int64
# comp_talent software services                                  int64
# comp_microstrategy                                             int64
# comp_american cybersystems, inc. (acs group)                   int64
# comp_hargray communications group, inc.                        int64
# comp_mantech international corporation                         int64
# comp_at&t it/engineering/technology                            int64
# comp_tti global                                                int64
# comp_otterbase                                                 int64
# comp_eliassen group                                            int64
# comp_atlas copco                                               int64
# comp_novetta llc                                               int64
# comp_kaman precision products, inc.                            int64
# comp_genesis10                                                 int64
# comp_transperfect                                              int64
# comp_christus health.                                          int64
# comp_calibre                                                   int64
# comp_icstars - transtech                                       int64
# comp_windhaven insurance™ insurance, inc.                      int64
# comp_the greysmith companies                                   int64
# comp_synergy business consulting, inc.                         int64
# comp_wells fargo                                               int64
# comp_magnum staffing                                           int64
# comp_kelly mitchell                                            int64
# comp_monarch staffing                                          int64
# comp_unified physician management                              int64
# comp_career developers, inc.                                   int64
# comp_platform 6 ltd                                            int64
# comp_corus360                                                  int64
# comp_rylem                                                     int64
# comp_federal-mogul                                             int64
# comp_rita staffing                                             int64
# comp_teksystems, inc                                           int64
# comp_solomon page                                              int64
# comp_nextgen information services, inc                         int64
# comp_wurth usa                                                 int64
# comp_ashley ellis                                              int64
# comp_stryker - premium career-site                             int64
# comp_ascent                                                    int64
# comp_mcgrath systems                                           int64
# comp_inovalon, inc.                                            int64
# comp_crg                                                       int64
# comp_jpmorgan chase & co.                                      int64
# comp_ace info solutions, inc                                   int64
# comp_equity staffing group                                     int64
# comp_electronic payment exchange (epx)                         int64
# comp_tracfone wireless inc.                                    int64
# comp_pionear                                                   int64
# comp_pyramid consulting, inc                                   int64
# comp_pacific western bank                                      int64
# comp_synergis                                                  int64
# comp_taj technologies, inc.                                    int64
# comp_modis                                                     int64
# comp_tpa technologies                                          int64
# comp_manpower                                                  int64
# comp_beacon hill staffing group, llc                           int64
# comp_asml                                                      int64
# comp_acclara solutions, llc                                    int64
# comp_hirestrong                                                int64
# comp_sparks group                                              int64
# comp_clearcaptions llc                                         int64
# comp_volt                                                      int64
# comp_premier placements                                        int64
# comp_abilitylab                                                int64
# comp_psr associates, inc.                                      int64
# comp_horizon search, inc.                                      int64
# comp_paladin, inc                                              int64
# comp_yale new haven health                                     int64
# comp_ipro                                                      int64
# comp_pointone recruiting solutions                             int64
# comp_koniag development corp                                   int64
# comp_sheridan healthcare                                       int64
# comp_career evolutions                                         int64
# comp_diverse systems group, llc                                int64
# comp_holtec international                                      int64
# comp_tetra tech                                                int64
# comp_select resources                                          int64
# comp_vaco technology                                           int64
# comp_remx it staffing                                          int64
# comp_washington suburban sanitary commission                   int64
# comp_talus partners, llc                                       int64
# comp_smile america partners                                    int64
# comp_consultnet                                                int64
# comp_pinnacle partners, inc                                    int64
# comp_kinetic personnel group                                   int64
# comp_softnice inc.                                             int64
# comp_integra kv                                                int64
# comp_amyx, inc                                                 int64
# comp_indotronix international corporation                      int64
# comp_new york community bancorp, inc.                          int64
# comp_progressive it                                            int64
# comp_ati physical therapy                                      int64
# comp_big tex trailers                                          int64
# comp_michael page                                              int64
# comp_emser tile llc                                            int64
# comp_austin fraser                                             int64
# comp_teledyne technologies                                     int64
# comp_alpine home air products                                  int64
# comp_poet, llc.                                                int64
# comp_alluvion staffing                                         int64
# comp_alliance data card services                               int64
# comp_hospitals insurance company                               int64
# comp_axelant                                                   int64
# comp_wwl/wupl                                                  int64
# comp_alleanza partners                                         int64
# comp_euclid innovations, inc                                   int64
# comp_atronix engineering                                       int64
# comp_uhs - valley hospital medical center                      int64
# comp_pyramid, inc                                              int64
# comp_rang technologies                                         int64
# comp_woongjin, inc                                             int64
# comp_healthgram                                                int64
# comp_vaco staffing                                             int64
# comp_atronix                                                   int64
# comp_pra group (nasdaq: praa)                                  int64
# comp_af group                                                  int64
# comp_meggitt                                                   int64
# comp_the chubb corporation                                     int64
# comp_5 star global recruitment partners, llc                   int64
# comp_amica insurance                                           int64
# comp_rpc company                                               int64
# comp_tricom technical services                                 int64
# comp_andis company                                             int64
# comp_hcl america inc                                           int64
# comp_la-z-boy                                                  int64
# comp_glocomms                                                  int64
# comp_the intersect group                                       int64
# comp_mdi group                                                 int64
# comp_glotel                                                    int64
# comp_mchenry county college                                    int64
# comp_geologics                                                 int64
# comp_mondelez international-                                   int64
# comp_national pen company                                      int64
# comp_ssi                                                       int64
# comp_it connect, llc                                           int64
# comp_renaissance personnel group                               int64
# comp_source select group                                       int64
# comp_imperium health management                                int64
# comp_usaa                                                      int64
# comp_frank recruitment group                                   int64
# comp_rsm us llp                                                int64
# comp_concurrent technologies corporation                       int64
# comp_aetea information technology inc.                         int64
# comp_gopher resource                                           int64
# comp_astrix technology group                                   int64
# comp_alls well health care services                            int64
# comp_nsc technologies                                          int64
# comp_wynn - las vegas                                          int64
# comp_baker's burgers inc                                       int64
# comp_loan by phone                                             int64
# comp_global employment solutions inc.                          int64
# comp_scan                                                      int64
# comp_altamed                                                   int64
# comp_the thor group                                            int64
# comp_smith personnel services, inc.                            int64
# comp_search enterprises, inc.                                  int64
# comp_redriver systems                                          int64
# comp_discount tire corporate careers                           int64
# comp_neotecra, inc.                                            int64
# comp_fanatics                                                  int64
# comp_agility                                                   int64
# comp_marsh & mclennan companies, inc                           int64
# comp_parker & lynch                                            int64
# comp_sun west mortgage company, inc                            int64
# comp_apex systems                                              int64
# comp_diverse tech staffing                                     int64
# comp_metasys technologies, inc.                                int64
# comp_orion systems integrators, llc.                           int64
# comp_mbc staffing                                              int64
# comp_think different it                                        int64
# comp_key solutions, inc.                                       int64
# comp_altair                                                    int64
# comp_ttec                                                      int64
# comp_jt3, llc.                                                 int64
# comp_insource group inc                                        int64
# comp_solegis, inc                                              int64
# comp_cottonwood financial                                      int64
# comp_commtech services, inc                                    int64
# comp_procter & gamble                                          int64
# comp_advanced technology services, inc.                        int64
# comp_pennymac                                                  int64
# comp_the select group                                          int64
# comp_university health system                                  int64
# comp_pentagon federal credit union                             int64
# comp_blue horizon tek solutions                                int64
# comp_pioneer data systems inc                                  int64
# comp_conscientia corp                                          int64
# comp_forrest johnson                                           int64
# comp_staffing technologies                                     int64
# comp_midland consultants                                       int64
# comp_catapult staffing                                         int64
# comp_tsi                                                       int64
# comp_federal home loan bank of des moines                      int64
# comp_amsted rail - asf keystone                                int64
# comp_diaspark, inc                                             int64
# comp_jll                                                       int64
# comp_hsbc                                                      int64
# comp_robert half technology                                    int64
# comp_oliver james associates                                   int64
# comp_maximus, inc.                                             int64
# comp_lutheran social services of illinois                      int64
# comp_nv energy                                                 int64
# comp_aetna                                                     int64
# comp_staffsource                                               int64
# comp_amazon.com                                                int64
# comp_corporate and technical recruiters                        int64
# comp_jfc global                                                int64
# comp_career smart                                              int64
# comp_banyan investment group                                   int64
# comp_jackson hewitt                                            int64
# comp_applus rtd                                                int64
# comp_hubbell inc                                               int64
# comp_care design new york                                      int64
# comp_magnetic inspection laboratory, inc.                      int64
# comp_total tech specialists                                    int64
# comp_alton manufacturing inc.                                  int64
# comp_experis                                                   int64
# comp_mri - ultimate placements, llc                            int64
# comp_henry schein, inc.                                        int64
# comp_mancan                                                    int64
# comp_allianceit                                                int64
# comp_public consulting group, inc.                             int64
# comp_the bartech group inc                                     int64
# comp_delta dallas                                              int64
# comp_randstad usa                                              int64
# comp_cyberthink, inc                                           int64
# comp_the sherwin-williams company                              int64
# comp_computershare, inc                                        int64
# comp_tsys                                                      int64
# comp_ues, inc.                                                 int64
# comp_tista science and technology corporation                  int64
# comp_the north west company                                    int64
# comp_american tower                                            int64
# comp_teleflex                                                  int64
# comp_centauri health solutions, inc.                           int64
# comp_ws packaging                                              int64
# comp_pra health sciences                                       int64
# comp_vital records control                                     int64
# comp_red sky consulting                                        int64
# comp_hirenetworks                                              int64
# comp_tegna                                                     int64
# comp_job juncture                                              int64
# comp_freedom health                                            int64
# comp_follett corporation                                       int64
# comp_reynolds consumer products inc                            int64
# comp_spectraforce technologies inc                             int64
# comp_ettain group                                              int64
# comp_federal reserve bank of kansas city                       int64
# comp_virginia farm bureau                                      int64
# comp_ryerson                                                   int64
# comp_accountemps                                               int64
# comp_pathfinders, inc.                                         int64
# comp_scientific games                                          int64
# comp_anderson frank                                            int64
# comp_woodgrain millwork                                        int64
# comp_conde group, inc                                          int64
# comp_easterseals, inc.                                         int64
# comp_northeast wisconsin technical college                     int64
# comp_technosmarts                                              int64
# comp_electrolux north america                                  int64
# comp_ajilon professional staffing                              int64
# comp_ensign services                                           int64
# comp_cse corp.                                                 int64
# comp_pcr-staffing                                              int64
# comp_igt                                                       int64
# comp_intertek                                                  int64
# comp_prairie consulting services                               int64
# comp_mckesson                                                  int64
# comp_american tire distributors                                int64
# comp_datalink                                                  int64
# comp_uc san diego                                              int64
# comp_united fire group                                         int64
# comp_cutting edge recruiting solutions                         int64
# comp_avangrid service company                                  int64
# comp_woz u                                                     int64
# comp_perma-pipe, inc.                                          int64
# comp_edgenuity inc.                                            int64
# comp_nok-kaihonua                                              int64
# comp_tech mahindra                                             int64
# comp_qbe north america                                         int64
# comp_lmi                                                       int64
# comp_motor coach industries                                    int64
# comp_fast switch, ltd.                                         int64
# comp_pharmavite® llc                                           int64
# comp_cameron craig group                                       int64
# comp_reyes holdings                                            int64
# comp_tech providers inc                                        int64
# comp_jumpvine                                                  int64
# comp_brightwing                                                int64
# comp_remedy intelligent staffing                               int64
# comp_deloitte                                                  int64
# comp_vyzer solutions                                           int64
# comp_the rowland group                                         int64
# comp_a plainscapital primelending company                      int64
# comp_metro systems, inc.                                       int64
# comp_us medical management                                     int64
# comp_parallon                                                  int64
# comp_crowe horwath llp                                         int64
# comp_integrated resources, inc                                 int64
# comp_kelly engineering resources                               int64
# comp_ardagh group                                              int64
# comp_w3r consulting                                            int64
# comp_hunter technical resources                                int64
# comp_hcs healthcare                                            int64
# comp_appleone                                                  int64
# comp_signature consultants                                     int64
# comp_keybank                                                   int64
# comp_smiths detection                                          int64
# comp_halo group                                                int64
# comp_specialists marketing services, inc.                      int64
# comp_boehringer ingelheim                                      int64
# comp_entegee, inc                                              int64
# comp_segrera associates                                        int64
# comp_solvay                                                    int64
# comp_energy engineering & consulting services, llc             int64
# comp_keiser university                                         int64
# comp_vwr international, llc                                    int64
# comp_thomas byrne associates                                   int64
# comp_talenthub worldwide                                       int64
# comp_idr                                                       int64
# comp_adkore megaforce                                          int64
# comp_compugain llc                                             int64
# comp_fifth third bank                                          int64
# comp_accounting now                                            int64
# comp_uline                                                     int64
# comp_digipulse technologies, inc                               int64
# comp_centria healthcare                                        int64
# comp_o'reilly auto parts                                       int64
# comp_lbx company                                               int64
# comp_express employment professionals of albany                int64
# comp_nesc                                                      int64
# comp_computer futures                                          int64
# comp_computer enterprises, inc. (cei)                          int64
# comp_gp strategies corporation                                 int64
# comp_coorstek inc                                              int64
# comp_detroit thermal systems                                   int64
# comp_nesco resource                                            int64
# comp_j.d. power                                                int64
# comp_jerry l jung company, inc                                 int64
# comp_nisum technologies, inc                                   int64
# comp_connectwise                                               int64
# comp_solution partners                                         int64
# comp_hru technical resources                                   int64
# comp_onyx government services, llc                             int64
# comp_advanced resources                                        int64
# comp_winmax                                                    int64
# comp_arcelormittal                                             int64
# comp_synovos                                                   int64
# comp_baptist health south florida                              int64
# comp_advantage resourcing                                      int64
# comp_agilent                                                   int64
# comp_vip search group                                          int64
# comp_the computer merchant, ltd                                int64
# comp_frontline source group                                    int64
# comp_university of kentucky                                    int64
# comp_equiant                                                   int64
# comp_nes global talent                                         int64
# comp_merritt staffing                                          int64
# comp_green key resources                                       int64
# comp_on-line systems, inc.                                     int64
# comp_lucas group - search                                      int64
# comp_townsend & associates                                     int64
# comp_software specialists inc                                  int64
# comp_iqvia                                                     int64
# comp_computer resource solutions                               int64
# comp_lynx technology partners inc                              int64
# comp_general mills inc.                                        int64
# comp_disys                                                     int64
# comp_the carlisle group                                        int64
# comp_ntt data                                                  int64
# comp_phoenixx systems, llc                                     int64
# comp_alphanumeric systems, inc.                                int64
# comp_bioinfo systems llc                                       int64
# comp_intertractor america corporation                          int64
# comp_stivers staffing services                                 int64
# comp_procom                                                    int64
# comp_svs group                                                 int64
# comp_u.s. bank                                                 int64
# comp_robert half management resources                          int64
# comp_austin allen company                                      int64
# comp_monroe staffing services                                  int64
# comp_pae                                                       int64
# comp_leaf commercial capital                                   int64
# comp_trakamerica                                               int64
# comp_elite human capital group                                 int64
# comp_syneos health                                             int64
# comp_the bontempo group                                        int64
# comp_talentbridge                                              int64
# comp_joule                                                     int64
# comp_correct care solutions                                    int64
# comp_cu medicine                                               int64
# comp_staff management                                          int64
# comp_interstate batteries                                      int64
# comp_db healthcare, inc.                                       int64
# comp_global recruiters network - seattle                       int64
# comp_express employment professionals                          int64
# comp_mystic lake casino and hotel                              int64
# comp_amzur technologies, inc                                   int64
# comp_ledgent search group                                      int64
# comp_m&t bank                                                  int64
# comp_oldcastle architectural                                   int64
# comp_brooksource                                               int64
# comp_veolia north america                                      int64
# comp_alltech int'l                                             int64
# comp_group o, inc.                                             int64
# comp_liquidhub                                                 int64
# comp_flybridge staffing                                        int64
# comp_success staffing agency                                   int64
# comp_capital insurance group                                   int64
# comp_karma automotive                                          int64
# comp_highmark health                                           int64
# comp_firstpro                                                  int64
# comp_software resources                                        int64
# comp_maxisit                                                   int64
# comp_cdi corporation                                           int64
# comp_union bank & trust                                        int64
# comp_the united states pharmacopeial convention                int64
# comp_federal home loan bank of dallas                          int64
# comp_usf holland inc.                                          int64
# comp_easter seals south florida                                int64
# comp_konik primestaff                                          int64
# comp_optomi, llc                                               int64
# comp_naic - national association of insurance commissioners    int64
# comp_intelliswift software, inc.                               int64
# comp_sabre systems, inc.                                       int64
# comp_bayside solutions                                         int64
# comp_liberty bank for savings                                  int64
# comp_collabera                                                 int64
# comp_test careerbuilderjob                                     int64
# comp_vantiv                                                    int64
# comp_datamasters                                               int64
# comp_medix                                                     int64
# ...
# comp_hca-nursing                                               int64
# comp_scandinavian tobacco group                                int64
# comp_aic (part of acs group)                                   int64
# comp_harris computer systems_ca                                int64
# comp_employer flexible                                         int64
# comp_v-soft consulting group, inc.                             int64
# comp_vencore                                                   int64
# comp_apple & associates                                        int64
# comp_resource solutions                                        int64
# comp_sabic innovative plastics                                 int64
# comp_publicis media                                            int64
# comp_the coca-cola company                                     int64
# comp_the matworks company                                      int64
# comp_paypal                                                    int64
# comp_molex                                                     int64
# comp_mdi group - it workforce solutions for what's next        int64
# comp_allegis global solutions                                  int64
# comp_transdev north america                                    int64
# comp_legacy treatment services                                 int64
# comp_jdc group                                                 int64
# comp_harvard resource solutions                                int64
# comp_ciox health                                               int64
# comp_proclinical                                               int64
# comp_fahrenheit it                                             int64
# comp_stonehenge resources, llc                                 int64
# comp_genpact                                                   int64
# comp_pasona                                                    int64
# comp_manpowergroup solutions                                   int64
# comp_apple leisure group                                       int64
# comp_amri                                                      int64
# comp_glazer's beer and beverage, llc                           int64
# comp_goodwill talentbridge                                     int64
# comp_vincentbenjamin                                           int64
# comp_fh maitland                                               int64
# comp_srimatrix inc                                             int64
# comp_tutor perini corporation                                  int64
# comp_atos                                                      int64
# comp_on-board family of companies                              int64
# comp_information technology group llc                          int64
# comp_cei group                                                 int64
# comp_next steps systems                                        int64
# comp_first data                                                int64
# comp_kellymitchell                                             int64
# comp_robert half finance & accounting                          int64
# comp_alliance of professionals & consultants, inc.             int64
# comp_ledgent finance & accounting                              int64
# comp_a-line staffing solutions                                 int64
# comp_blue shield of california                                 int64
# comp_elevate services, inc.                                    int64
# comp_visionpro                                                 int64
# comp_spartan resources                                         int64
# comp_technology consulting, inc                                int64
# comp_irvine technology corporation                             int64
# comp_gm financial                                              int64
# comp_ups it                                                    int64
# comp_superior group                                            int64
# comp_sp plus corporation                                       int64
# comp_hallmark totaltech, inc.                                  int64
# comp_jupiter consulting                                        int64
# comp_mri- management recruiters of mt. adams                   int64
# comp_hydro                                                     int64
# comp_washington metropolitan area transit authority            int64
# comp_advantage solutions                                       int64
# comp_chasesource                                               int64
# comp_axelon services corporation                               int64
# comp_equis staffing                                            int64
# comp_apex life sciences                                        int64
# comp_nika                                                      int64
# comp_gus perdikakis associates inc                             int64
# comp_medical mutual                                            int64
# comp_kinetic personnel group, inc                              int64
# comp_hamilton-ryker company                                    int64
# comp_systemtec, inc.                                           int64
# comp_globe life and accident insurance company                 int64
# comp_dun & bradstreet, inc.                                    int64
# comp_circor international, inc                                 int64
# comp_kforce finance and accounting                             int64
# comp_ametek inc.                                               int64
# comp_think anew, llc                                           int64
# comp_alpha consulting                                          int64
# comp_genesis 10                                                int64
# comp_global technology associates                              int64
# comp_d3 air & space operations                                 int64
# comp_lehigh technical                                          int64
# comp_zoll lifevest                                             int64
# comp_atlas data systems                                        int64
# comp_aym alliance                                              int64
# comp_grant thornton                                            int64
# comp_secura insurance                                          int64
# comp_jsk recruiting, inc                                       int64
# comp_latitude 36                                               int64
# comp_knf&t, inc                                                int64
# comp_caloptima                                                 int64
# comp_lake city group                                           int64
# comp_otc direct, inc.                                          int64
# comp_micore solutions inc.                                     int64
# comp_emerald resource group                                    int64
# comp_managed care staffers                                     int64
# comp_hunter international                                      int64
# comp_stanford health care                                      int64
# comp_unitedhealth group                                        int64
# comp_lyondellbasell                                            int64
# comp_sgl carbon, llc                                           int64
# comp_savantis solutions llc                                    int64
# comp_oldcastle materials                                       int64
# comp_russell tobin & associates                                int64
# comp_the main street america group                             int64
# comp_jupiter consulting services                               int64
# comp_hirenexus                                                 int64
# comp_continental ag                                            int64
# comp_amiti consulting                                          int64
# comp_clearbridge technology group llc                          int64
# comp_imagine one technology                                    int64
# comp_roc search inc                                            int64
# comp_the right staff llc                                       int64
# comp_abilities network inc                                     int64
# comp_carrington mortgage holdings                              int64
# comp_huntington national bank                                  int64
# comp_jerry l jung company, inc.                                int64
# comp_kelly services                                            int64
# comp_great american insurance                                  int64
# comp_gwinnett medical center                                   int64
# comp_health services advisory group, inc.                      int64
# comp_southern california edison                                int64
# comp_top pharmaceutical company                                int64
# comp_the bell company.                                         int64
# comp_tier 1 investment banks                                   int64
# comp_spaceflight industries                                    int64
# comp_globe acceptance, inc.                                    int64
# comp_drummers lane corporate                                   int64
# comp_amsted rail                                               int64
# comp_general dynamics information technology                   int64
# comp_real staffing                                             int64
# comp_trinity system office                                     int64
# comp_cgs administrators, llc                                   int64
# comp_biotelemetry                                              int64
# comp_accruepartners                                            int64
# comp_sodexo                                                    int64
# comp_3coast                                                    int64
# deg_high school                                                int64
# deg_doctorate                                                  int64
# deg_4 year degree                                              int64
# deg_graduate degree                                            int64
# deg_none                                                       int64
# deg_2 year degree                                              int64
# travel_road warrior                                            int64
# travel_none                                                    int64
# travel_some                                                    int64
# travel_up to 50%                                               int64
# travel_up to 25%                                               int64
# travel_negligible                                              int64
# state_TN                                                       int64
# state_MD                                                       int64
# state_UT                                                       int64
# state_OR                                                       int64
# state_PA                                                       int64
# state_TX                                                       int64
# state_MA                                                       int64
# state_VA                                                       int64
# state_OH                                                       int64
# state_ME                                                       int64
# state_DE                                                       int64
# state_GU                                                       int64
# state_MI                                                       int64
# state_VI                                                       int64
# state_MS                                                       int64
# state_MO                                                       int64
# state_MN                                                       int64
# state_IL                                                       int64
# state_GA                                                       int64
# state_IN                                                       int64
# state_KS                                                       int64
# state_MT                                                       int64
# state_ID                                                       int64
# state_IA                                                       int64
# state_KY                                                       int64
# state_RI                                                       int64
# state_CO                                                       int64
# state_OK                                                       int64
# state_AL                                                       int64
# state_VT                                                       int64
# state_PR                                                       int64
# state_WA                                                       int64
# state_CA                                                       int64
# state_AK                                                       int64
# state_AS                                                       int64
# state_AR                                                       int64
# state_CT                                                       int64
# state_AZ                                                       int64
# state_NH                                                       int64
# state_NJ                                                       int64
# state_NM                                                       int64
# state_SC                                                       int64
# state_WI                                                       int64
# state_NC                                                       int64
# state_ND                                                       int64
# state_NE                                                       int64
# state_LA                                                       int64
# state_NY                                                       int64
# state_HI                                                       int64
# state_DC                                                       int64
# state_WY                                                       int64
# state_SD                                                       int64
# state_FL                                                       int64
# state_NV                                                       int64
# state_WV                                                       int64
# salary_min                                                     float64
# salary_avg                                                     float64
# salary_max                                                     float64
# title_intern                                                   int64
# title_lead                                                     int64
# title_principal                                                int64
# title_chief                                                    int64
# title_senior                                                   int64
# title_junior                                                   int64
# title_data                                                     int64
# title_ml                                                       int64
# title_database                                                 int64
# title_ai                                                       int64
# title_business                                                 int64
# title_software                                                 int64
# title_sql                                                      int64
# title_financial                                                int64
# title_analyst                                                  int64
# title_intelligence                                             int64
# title_engineer                                                 int64
# title_developer                                                int64
# title_scientist                                                int64
# title_administrator                                            int64
# title_architect                                                int64
# dtypes: float64(4), int64(1162), object(1)
# memory usage: 25.0+ MB
